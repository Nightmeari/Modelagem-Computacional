# %% [markdown]
# Para o exercício a seguir desenvolva um programa em Python para obter a
# solução. Utilize como referência os códigos estudados e as funções
# específicas.

# %% [markdown]
# Quando um fluido escoa sobre uma superfície, a taxa de transferência de calor
# 𝑞̇ (J/s) na superfície é dada pela expressão:
# em que k é a condutividade térmica (J/s.m.K), T é a temperatura K e y é a
# distância normal à superfície (cm). Medidas da temperatura do fluido escoando
# sobre a superfície foram feitas utilizando um termopar. Os valores obtidos estão
# na tabela a seguir.
