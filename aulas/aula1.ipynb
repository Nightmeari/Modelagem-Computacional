# %% [markdown]
# Ex1

# %%
salario = 14.25
total = (163 *salario) + (20*2*salario)
print(total)

# %% [markdown]
# Ex2
# leia três números reais e informe se eles
# constituem os lados de um triângulo
# Em caso afirmativo, informe se o
# triângulo é equilátero, isósceles ou escaleno
# a soma dos dois lados menores deve ser maior que
# o lado maior

# %%
a,b,c = int(input("Lado A:\n")), int(input("Lado B:\n")), int(input("Lado B:\n"))
maior = max(a, b, c)
soma = a + b + c
menores = soma - maior

if menores > maior:
    if a == b == c:
        print("Esse triângulo é equilátero.")
    elif a == b or a == c:
        print("Esse triângulo é isóceles.")
    else:
        print("Esse triângulo é escaleno.")
else:
    print("Não é um triangulo")
# Out:
# Não é um triangulo

# %% [markdown]
# ex3
# Elabore um programa que efetue a leitura de valores positivos inteiros até
# que zero ou um valor negativo seja informado. Ao final, devem ser
# apresentados o maior e menor valores informados pelo usuário, a
# quantidade de valores, a soma e a média de todos.

# %%
i = 1;
lista = []
while i > 0:
    i = int(input("Número"))
    if i > 0:
        lista.append(i)

print(max(lista), min(lista), len(lista), sum(lista), sum(lista) / len(lista))
# Out:
# 12 10 3 33 11.0

# %% [markdown]
# ex6
# Faça um programa que faça um gráfico do tipo plot para as funções seno
# e cosseno. Importe as bibliotecas numpy (para usar as funções linspace,
# sin e cos) e matplotlib.pyplt. Caso precise de ajuda, consulte

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)

seno = np.sin(x)
cosseno = np.cos(x)

plt.plot(x, seno, label="Seno")
plt.plot(x, cosseno, label="Cosseno")


plt.title("Gráfico do Seno e Cosseno")
plt.xlabel("x")
plt.ylabel("Valor")
plt.legend()
plt.grid(True)

plt.show()
